# %%
# Import pandas
import pandas as pd

# Specify the path to your text file
file_path = 'C:\\Users\\User\\SDA490\\SelectedComments'

# Read the text file and create a DataFrame
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()
    # Strip newline characters from each line
    lines = [line.strip() for line in lines if line.strip()]

# Create a DataFrame with a single column "text"
df = pd.DataFrame(lines, columns=['text'])

# Display the first few entries to verify
print(df)
# Out:
#                                                   text
# 0        Calgary Text 2: Calgary Is An Underrated City
# 1    I've found likeable things in every city I've ...
# 2    kinda wish this 'Calgary is a redneck backwate...
# 3    You will experience this anywhere you go that ...
# 4      nsurance (property and car) is ridiculous here.
# ..                                                 ...
# 96   Short answer: yes, it’s worth it. Long answer:...
# 97   If you are trans, you WILL make friends here. ...
# 98   Socializing here is tricky, though. If you cho...
# 99   If you can remember that and afford this city,...
# 100  Until you mentioned it now, I never realized w...
#
# [101 rows x 1 columns]

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize the sentiment intensity analyzer
sia = SentimentIntensityAnalyzer()

# Calculate sentiment scores for each post
df['sentiment_scores'] = df['text'].apply(lambda x: sia.polarity_scores(x))
df['compound'] = df['sentiment_scores'].apply(lambda x: x['compound'])

# Determine the overall sentiment based on the compound score
df['overall_sentiment'] = df['compound'].apply(lambda x: 'positive' if x > 0 else ('negative' if x < 0 else 'neutral'))

# Example output
print(df[['text', 'overall_sentiment']])
# Out:
#                                                   text overall_sentiment
# 0        Calgary Text 2: Calgary Is An Underrated City           neutral
# 1    I've found likeable things in every city I've ...          positive
# 2    kinda wish this 'Calgary is a redneck backwate...          negative
# 3    You will experience this anywhere you go that ...          positive
# 4      nsurance (property and car) is ridiculous here.          negative
# ..                                                 ...               ...
# 96   Short answer: yes, it’s worth it. Long answer:...          positive
# 97   If you are trans, you WILL make friends here. ...          positive
# 98   Socializing here is tricky, though. If you cho...          negative
# 99   If you can remember that and afford this city,...          positive
# 100  Until you mentioned it now, I never realized w...          positive
#
# [101 rows x 2 columns]

# %%
import pandas as pd

# Set the pandas display options to show all rows
pd.set_option('display.max_rows', None)

# Assuming 'df' is your DataFrame
print(df[['text', 'overall_sentiment']])
# Out:
#                                                   text overall_sentiment
# 0        Calgary Text 2: Calgary Is An Underrated City           neutral
# 1    I've found likeable things in every city I've ...          positive
# 2    kinda wish this 'Calgary is a redneck backwate...          negative
# 3    You will experience this anywhere you go that ...          positive
# 4      nsurance (property and car) is ridiculous here.          negative
# 5    Nah, everything else is more expensive to comp...          negative
# 6                               It's not, though… (-1)           neutral
# 7    Is it though? Asking genuinely. Everything is ...          negative
# 8    Well yeah cuz 10 years ago everyone was saying...          positive
# 9    Well the Alberta government isn't complaining....          positive
# 10   I’m working on our code in the meantime Thank ...          positive
# 11       Calgary Text 2: Calgary Is An Underrated City           neutral
# 12   Not going to lie, when I thought of Alberta 2 ...          negative
# 13   I think this has to do with what’s portrayed i...           neutral
# 14   Every time I visit family in the GTA and their...          positive
# 15   Of course, none of them have actually visited ...           neutral
# 16   It's unfortunate that reality does not get ref...          negative
# 17   I'm always amused when Torontonians shit on Ca...          negative
# 18   Just look at the mayors Toronto elects (Rob Fo...           neutral
# 19            Weather comments bug me similarly.  (-1)           neutral
# 20   People can google and compare decades of weath...           neutral
# 21   Calgary gets a few weeks of freezing cold whic...          positive
# 22   I'll gladly take the dry cold and light fluffy...          negative
# 23   Calgary is objectively warmer than Toronto in ...          positive
# 24   That's before even counting the fact that Calg...          positive
# 25   Not even comparable, winter in Calgary is far ...          positive
# 26   Even Calgarians don't realize how good winter ...          negative
# 27   Having spent a decade in northern Saskatchewan...          negative
# 28                                      Calgary Text 3           neutral
# 29   Food, music, people, and culture are what I mi...          negative
# 30   The only thing that I enjoy is the lack of car...          positive
# 31   Check out Stay Vigilant Productions on Instagr...          positive
# 32   Not sure how long you’ve been here but a lot o...          negative
# 33   Been here my entire life (34 years) and it’s t...           neutral
# 34   There’s so much growth (which is great for the...          positive
# 35                                 Calgary Text File 4           neutral
# 36   Calgary is known as a beef town, but yet there...          positive
# 37   This! All I want is a decent smoke house, and ...          positive
# 38   Big T is the worst option for smoked meat. Try...          negative
# 39   Palomino is hit and miss. I've had absolutely ...          positive
# 40   I have been to the Palomino twice, and the fir...           neutral
# 41   Agreed, would also add Jane Bond BBQ and Sky R...          positive
# 42   I thought we had good BBQ until I went to sout...          positive
# 43   We have good BBQ, its just they have struck a ...          negative
# 44                               Vancouver Move Text 2           neutral
# 45   Vancouver renters are paying more for living s...           neutral
# 46   The 516 sqft apartment I signed a lease for 10...          positive
# 47   The last condo I looked at when I was interest...          positive
# 48   Located around 41st and Victoria, it sold for ...          positive
# 49   Nothing new I suppose like everyone else is sa...          negative
# 50   You read that right. The city is enforcing a m...           neutral
# 51   depressing that the city and other levels of g...          negative
# 52   They aren't doing more to add to our problems....          negative
# 53                               Vancouver Text file 4           neutral
# 54   My house has risen in value by about 90% of ou...          positive
# 55   liquidity crisis is coming house will be down ...          negative
# 56   That will depend on if the fed will let the ma...          negative
# 57            Fed has something called a money printer           neutral
# 58   No they have something called a computer and o...          negative
# 59   A lot of land leeches on this sub lately that ...          negative
# 60   Politicians need to see the effect that housin...           neutral
# 61   You are exactly the type of immigrant we want ...          positive
# 62   Getting the Toronto Star to do a profile on yo...          positive
# 63              How people are holding up in vancouver           neutral
# 64   Myself as well. I'm genuinely terrified of any...          negative
# 65   Vancouver is not bad if you are a young profes...          positive
# 66   My wife really wants to buy a house and she’s ...          negative
# 67   I just moved here from Germany and honestly, i...          negative
# 68   I make around the same, and I don’t have kids/...          positive
# 69                                 Moving to Vancouver           neutral
# 70   I love this city, I hope I die in this city. (+1)          positive
# 71   Don’t recommend moving here. Not only is it ex...          positive
# 72   I recommend getting into a time machine and go...          positive
# 73   Housing is diabolical and nobody can afford th...          positive
# 74   1 bedrooms in the suburbs are going for $2500....          negative
# 75   Text file - Where have house prices risen the ...           neutral
# 76   "The bubble will definitely burst this decade ...          positive
# 77   "Wait, so everything besides big-ticket items ...          negative
# 78   "The loonie got really strong this past year b...          negative
# 79   38. "As a Canadian, this just validates my fea...          negative
# 80   39. "That’s a mood. As someone who’s graduatin...          negative
# 81   Text 3- For those who have relocated from Vanc...           neutral
# 82   Depends why your moving, what stage of life yo...          negative
# 83   Agreed! I was happy in Vancouver as a young ad...          positive
# 84   Art culture here is different - In my experien...          positive
# 85   My situation may be different then others but ...          positive
# 86   I know you hear those things about Alberta pol...          negative
# 87   Are you having to move into smaller units or s...          positive
# 88   I have to continue living with my ex because I...           neutral
# 89   Prince George area, plenty of work but you hav...           neutral
# 90   A lot of people are considering that area now,...           neutral
# 91   There’s loads of space and plenty of new devel...          positive
# 92   To anyone on the fence, there’s still hope, an...          positive
# 93   I’m moving to Kelowna where rentals are more a...          positive
# 94   Now, our building will be torn down and we can...          negative
# 95   Thinking about moving to Vancouver in 2022. Is...          positive
# 96   Short answer: yes, it’s worth it. Long answer:...          positive
# 97   If you are trans, you WILL make friends here. ...          positive
# 98   Socializing here is tricky, though. If you cho...          negative
# 99   If you can remember that and afford this city,...          positive
# 100  Until you mentioned it now, I never realized w...          positive
